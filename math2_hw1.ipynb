# %% [markdown]
# ### Задача 1
#
# **Рассмотрим пример 2 из методички. Чтобы посчитать вероятность такого события, нужно использовать сочетания или размещения? Ответ необходимо обосновать. (Две игральные кости: При этом будем находить частоту случайного события 𝐵, при котором на первой кости выпало 1, а на второй — 2.)**

# %% [markdown]
# Размещение с повторениями, так как порядок важен. Нет условия на то, что событие (2,1) тоже искомое

# %% [markdown]
# ### Задача 2
#
# **Группа студентов изучает 10 различных дисциплин. Сколькими способами можно составить расписание на понедельник, если в этот день должно быть 4 разных занятия?**

# %% [markdown]
# Используем размещения без повторов, так как занятия РАЗНЫЕ, но порядок важен
#
# Число размещений из $n$ по $k$:
#
# $$A_n^k = \frac{n!}{(n - k)!}$$

# %%
import numpy as np
A=np.math.factorial(10)/np.math.factorial(10-4)
print(f'Существует {A} вариантов составления расписания на понедельник')
# Out:
# Существует 5040.0 вариантов составления расписания на понедельник

# %% [markdown]
# ### Задача 3
#
# **Семь человек рассаживаются наудачу на скамейке. Какова вероятность того, что два определённых человека будут сидеть рядом?**

# %% [markdown]
# Число перестановок:
#
# $$A_n = {n!}$$

# %% [markdown]
# Допустим, что искомые люди - это 1 и 2, а 0 обозначим любого другого человека из этих семи. Тогда нас интересуют размещения в которых:
#         1200000
#         2100000
#         0120000
#         0210000
#         0012000
#         0021000
#         0001200
#         0002100
#         0000120
#         0000210
#         0000012
#         0000021
#
# Те 12 вариантов по 5 перестановок, значит:
#
#
# $$P = \frac{12*5!}{7!}$$

# %%
print(f'Искомая вероятность {12*np.math.factorial(5)/np.math.factorial(7)}')
# Out:
# Искомая вероятность 0.2857142857142857

# %% [markdown]
# ### Задача 4
#
# **Из 60 вопросов, входящих в экзаменационные билеты, студент знает 50. Какова вероятность того, что среди трёх наугад выбранных вопросов студент знает: а) все? б) два?**

# %% [markdown]
# Общее количество сочетаний по 3 из 60:
#     $$A = \frac{60!}{(60-3)!*3!}$$

# %% [markdown]
# Из них количество сочетаний с теми вопросами, которые он знает:
#     $$An = \frac{50!}{(50-3)!*3!}$$

# %%
A=np.math.factorial(60)/(np.math.factorial(57) * np.math.factorial(3))
An=np.math.factorial(50)/(np.math.factorial(47) * np.math.factorial(3))
print(f'Вероятность того, что студент вытянет три известных ему вопроса: {An/A}')
# Out:
# Вероятность того, что студент вытянет три известных ему вопроса: 0.5727644652250146

# %% [markdown]
# Различные сочетания известных билетов и неизвестного можно получить, перемножив сочетания для известных и неизвестного билетов:
#     $$An = \frac{50!}{(50-2)!*2!}$$
#     $$Au = \frac{10!}{(10-1)!*1!}$$
# И получить вероятность того, что один из вопросов студенту будет неизвестен:
#      $$P_2 = \frac{(An*Au)}{A}$$

# %%
A=np.math.factorial(60)/(np.math.factorial(57) * np.math.factorial(3))
An=np.math.factorial(50)/(np.math.factorial(50-2) * np.math.factorial(2))
Au=np.math.factorial(10)/(np.math.factorial(10-1) * np.math.factorial(1))
print(f'Вероятность того, что студент вытянет только два известных ему вопроса: {(An*Au)/A}')
# Out:
# Вероятность того, что студент вытянет только два известных ему вопроса: 0.35797779076563413

# %% [markdown]
# ### Задача 5
#
# **Бросается игральная кость. Пусть событие A - появление чётного числа, событие B - появление числа больше трёх. Являются ли эти события независимыми?**

# %% [markdown]
# События являются зависимыми - тк наступление одного (появление четного числа) изменяет вероятность второго (то, что это число больше трех)

# %% [markdown]
# ### Задача 6
#
# **Допустим, имеется некоторая очень редкая болезнь (поражает 0.1% населения). Вы приходите к врачу, вам делают тест на эту болезнь, и тест оказывается положительным. Врач говорит вам, что этот тест верно выявляет 99 % больных этой болезнью и всего лишь в 1% случаев даёт ложный положительный ответ.**
#
# Вопрос: вакова вероятность, что вы действительно больны ей?
#
# Подсказка: используйте формулу Байеса с раскрытием знаменателя с помощью формулы полной вероятности.

# %% [markdown]
# Если В - вероятность заболеть этой болезнью, то A вероятность положительного теста на эту болезнь
#
# $$P(B\:|\:A) = \frac{P(A\:|\:B) \cdot P(B)}{P(A)}$$
#
# Вероятность $${P(A\:|\:B)= 0.99}$$
#
# $${P(B)= 0.001}$$
#
# Полная вероятность для A:
# $${P(A)= 0.99*0.001+0.01*(1-0.001)}$$

# %%
# 𝑃(𝐴)
0.99*0.001+0.01*(1-0.001)
# Out:
# 0.01098

# %%
print(f'Вероятность быть больным при положительном результате теста: {0.99*0.001/(0.01098)}')
# Out:
# Вероятность быть больным при положительном результате теста: 0.09016393442622951
